# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_data = pd.read_csv('Resources/avg_rain_state.csv')
rain_data.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_data))
tick_locations = [_+0.4 for _ in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_data['Inches'], color='r', alpha=0.5, align='edge')
plt.xticks(tick_locations, rain_data['State'], rotation ='vertical')
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x279787a68d0>,
#   <matplotlib.axis.XTick at 0x279787a6278>,
#   <matplotlib.axis.XTick at 0x27978534ac8>,
#   <matplotlib.axis.XTick at 0x2797886c4a8>,
#   <matplotlib.axis.XTick at 0x2797886c940>,
#   <matplotlib.axis.XTick at 0x2797886ce80>,
#   <matplotlib.axis.XTick at 0x2797887d438>,
#   <matplotlib.axis.XTick at 0x2797887d9b0>,
#   <matplotlib.axis.XTick at 0x2797887df28>,
#   <matplotlib.axis.XTick at 0x279788834e0>,
#   <matplotlib.axis.XTick at 0x2797887d908>,
#   <matplotlib.axis.XTick at 0x279788836a0>,
#   <matplotlib.axis.XTick at 0x27978883c18>,
#   <matplotlib.axis.XTick at 0x2797888b1d0>,
#   <matplotlib.axis.XTick at 0x2797888b748>,
#   <matplotlib.axis.XTick at 0x2797888bcc0>,
#   <matplotlib.axis.XTick at 0x27978892278>,
#   <matplotlib.axis.XTick at 0x279788927f0>,
#   <matplotlib.axis.XTick at 0x27978892d68>,
#   <matplotlib.axis.XTick at 0x27978892668>,
#   <matplotlib.axis.XTick at 0x2797888b6a0>,
#   <matplotlib.axis.XTick at 0x27978883cc0>,
#   <matplotlib.axis.XTick at 0x2797889b828>,
#   <matplotlib.axis.XTick at 0x2797889bda0>,
#   <matplotlib.axis.XTick at 0x279788a1358>,
#   <matplotlib.axis.XTick at 0x279788a18d0>,
#   <matplotlib.axis.XTick at 0x279788a1e48>,
#   <matplotlib.axis.XTick at 0x279788a8400>,
#   <matplotlib.axis.XTick at 0x279788a8978>,
#   <matplotlib.axis.XTick at 0x279788a19b0>,
#   <matplotlib.axis.XTick at 0x27978861f60>,
#   <matplotlib.axis.XTick at 0x279788a8e10>,
#   <matplotlib.axis.XTick at 0x279788b13c8>,
#   <matplotlib.axis.XTick at 0x279788b1940>,
#   <matplotlib.axis.XTick at 0x279788b1eb8>,
#   <matplotlib.axis.XTick at 0x279788b5470>,
#   <matplotlib.axis.XTick at 0x279788b59e8>,
#   <matplotlib.axis.XTick at 0x279788b5f60>,
#   <matplotlib.axis.XTick at 0x279788b53c8>,
#   <matplotlib.axis.XTick at 0x279788b17b8>,
#   <matplotlib.axis.XTick at 0x279788b9400>,
#   <matplotlib.axis.XTick at 0x279788b9a20>,
#   <matplotlib.axis.XTick at 0x279788b9e80>,
#   <matplotlib.axis.XTick at 0x279788c4550>,
#   <matplotlib.axis.XTick at 0x279788c4ac8>,
#   <matplotlib.axis.XTick at 0x279788c80f0>,
#   <matplotlib.axis.XTick at 0x279788c85f8>,
#   <matplotlib.axis.XTick at 0x279788c8b70>,
#   <matplotlib.axis.XTick at 0x279788c48d0>,
#   <matplotlib.axis.XTick at 0x279788b1898>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0,max(rain_data['Inches'])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title('Average Rain per State')
plt.xlabel('State')
plt.ylabel('Average Amount of\nRainfall (Inches)')
# Out:
# Text(0, 0.5, 'Average Amount of\nRainfall (Inches)')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig('Images/avg_state_rain_output.png')
plt.show()
