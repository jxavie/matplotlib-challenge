# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

# %%
#Bonus. Create list of scoop prices
scoop_price = [random.randint(1,10) for _ in range(0,len(temp))]
scoop_price
# Out:
# [1, 8, 10, 9, 5, 5, 3, 8, 1, 2, 7, 7]

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(temp, sales, marker='o', facecolors='red', edgecolors='black')

#Bonus. Plot using scoop_price as size of dots
plt.scatter(temp, sales, marker='o', facecolors='red', edgecolors='black', s=scoop_price)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set the upper and lower limits of our y axis
plt.ylim(180,620)
# Out:
# (180, 620)

# %%
# Set the upper and lower limits of our x axis
plt.xlim(11,26)
# Out:
# (11, 26)

# %%
# Create a title, x label, and y label for our chart
plt.title('Ice Cream Sales v Temperature')
plt.xlabel('Temperature (Celsius)')
plt.ylabel('Sales(Dollars)')
# Out:
# Text(0, 0.5, 'Sales(Dollars)')

# %%
# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.

plt.savefig('Images/IceCreamSales_Output.png')
plt.show()
